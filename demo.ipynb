# %%
from segmentation_robustness_framework import RobustnessEvaluation

# %%
config_path = "configs/config.yaml"

with open(config_path, "r") as f:
    print(f.read())
# Out:
# model:
#   name: "FCN"
#   encoder: "resnet101"
#   weights: "coco_with_voc_labels"
#   num_classes: 21
#   device: "cuda"
#
# attacks:
#   - name: "FGSM"
#     epsilon: [0.05, 0.125, 0.25]
#
# dataset:
#   name: "VOC"
#   root: "../datasets/VOCdevkit/VOC2012/"
#   split: "val"
#   image_shape: [512, 376]
#   max_images: 2
#
# output:
#   save_dir: "./runs/"
#   save_images: true
#   save_log: true

# %%
srf = RobustnessEvaluation(config_path=config_path)

# %%
srf.run()
